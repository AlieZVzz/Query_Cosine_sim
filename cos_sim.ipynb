# %%
import jieba
import jieba.analyse
  
def words2vec(words1=None, words2=None):
    v1 = []
    v2 = []
    tag1 = jieba.analyse.extract_tags(words1, withWeight=True)
    tag2 = jieba.analyse.extract_tags(words2, withWeight=True)
    tag_dict1 = {i[0]: i[1] for i in tag1}
    tag_dict2 = {i[0]: i[1] for i in tag2}
    merged_tag = set(tag_dict1.keys()) | set(tag_dict2.keys())
    for i in merged_tag:
        if i in tag_dict1:
            v1.append(tag_dict1[i])
        else:
            v1.append(0)
        if i in tag_dict2:
            v2.append(tag_dict2[i])
        else:
            v2.append(0)
    return v1, v2
  
  
def cosine_similarity(vector1, vector2):
    dot_product = 0.0
    normA = 0.0
    normB = 0.0
    for a, b in zip(vector1, vector2):
        dot_product += a * b
        normA += a ** 2
        normB += b ** 2
    if normA == 0.0 or normB == 0.0:
        return 0
    else:
        return round(dot_product / ((normA**0.5)*(normB**0.5)) * 100, 2)
      
def cosine(str1, str2):
    vec1, vec2 = words2vec(str1, str2)
    return cosine_similarity(vec1, vec2)

# %%
import pandas as pd
data=pd.read_csv('汉语.csv')
query = list(data['query'])

# %%
for i in range(1, len(data['query'])):
    cos_sim = cosine(query[i-1],query[i])
    print(cos_sim)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\ASUS\AppData\Local\Temp\jieba.cache
# Loading model cost 0.447 seconds.
# Prefix dict has been built successfully.
# 0.0
# 0.0
# 76.29
# 91.36
# 45.67
# 65.52
# 73.09
# 86.04
# 86.04
# 73.09
# 65.52
# 64.71
# 73.89
# 31.11
# 74.41
# 49.66
# 48.84
# 87.12
# 82.71
# 87.17
# 40.51
# 51.03
# 38.66
# 100.0
# 75.77
# 93.75
# 68.35
# 76.36
# 61.86
# 90.85
# 48.53
# 61.86
# 0.0
# 67.58
# 0.0
# 62.07
# 74.82
# 74.82
# 61.84
# 76.03
# 66.61
# 79.88
# 51.21
# 76.8
# 62.73
# 69.53
# 69.53
# 69.53
# 69.53
# 23.69
# 75.81
# 60.77
# 86.71
# 49.82
# 49.82
# 72.91
# 68.41
# 68.41
# 100.0
# 65.94
# 73.09
# 73.09
# 80.0
# 35.8
# 86.81
# 65.77
# 72.91
# 58.83
# 77.05
# 63.32
# 74.82
# 0.0
# 0.0
# 85.13
# 78.79
# 80.39
# 84.63
# 81.51
# 78.68
# 16.7
# 16.7
# 33.01
# 79.88
# 74.31
# 74.31
# 100.0
# 69.94
# 0.0
# 100.0
# 100.0
# 100.0
# 65.0
# 66.92
# 79.88
# 0.0
# 0.0
# 71.51
# 0
# 0
# 87.55
# 90.65
# 55.11
# 80.4
# 44.41
# 39.82
# 89.67
# 80.4
# 55.11
# 90.65
# 87.55
# 0.0
# 0.0
# 50.6
# 50.6
# 79.88
# 66.92
# 65.0
# 72.57
# 38.7
# 0.0
# 24.23
# 80.06
# 43.33
# 43.33
# 0.0
# 90.22
# 65.94
# 44.27
# 87.12
# 100.0
# 69.53
# 73.09
# 50.82
# 69.53
# 85.13
# 100.0
# 78.28
# 60.12
# 62.73
# 45.07
# 46.35
# 90.89
# 94.33
# 63.12
# 51.46
# 88.03
# 75.78
# 76.34
# 62.15
# 59.19
# 59.19
# 80.75
# 76.66
# 77.57
# 90.4
# 57.79
# 100.0
# 97.33
# 48.95
# 80.81
# 84.63
# 84.63
# 69.14
# 69.14
# 65.0
# 95.5
# 63.05
# 0.0
# 100.0
# 65.75
# 69.84
# 77.11
# 88.4
# 0.0
# 86.22
# 73.42
# 25.34
# 0.0
# 65.0
# 52.4
# 67.72
# 89.32
# 53.64
# 100.0
# 91.91
# 52.99
# 100.0
# 100.0
# 62.3
# 100.0
# 72.01
# 86.71
# 79.2
# 100.0
# 82.46
# 82.46
# 81.53
# 77.96
# 100.0

# %%
print(cosine('顿月顿珠的书','顿月顿珠'))
# Out:
# 100.0

# %%
print(cosine('顿月顿珠','顿月顿珠的视频'))
# Out:
# 84.63
